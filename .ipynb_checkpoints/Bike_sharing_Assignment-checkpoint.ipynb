# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('day.csv')

# %%
data
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  01-01-2018       1   0     1        0        6           0
# 1          2  02-01-2018       1   0     1        0        0           0
# 2          3  03-01-2018       1   0     1        0        1           1
# 3          4  04-01-2018       1   0     1        0        2           1
# 4          5  05-01-2018       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 725      726  27-12-2019       1   1    12        0        4           1
# 726      727  28-12-2019       1   1    12        0        5           1
# 727      728  29-12-2019       1   1    12        0        6           0
# 728      729  30-12-2019       1   1    12        0        0           0
# 729      730  31-12-2019       1   1    12        0        1           1
#
#      weathersit       temp     atemp      hum  windspeed  casual  registered  \
# ...

# %%
data.shape
# Out:
# (730, 16)

# %%
data.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean   365.500000    2.498630    0.500000    6.526027    0.028767    2.997260
# std    210.877136    1.110184    0.500343    3.450215    0.167266    2.006161
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.250000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    365.500000    3.000000    0.500000    7.000000    0.000000    3.000000
# 75%    547.750000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    730.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean     0.683562    1.394521   20.319259   23.726322   62.765175   12.763620
# ...

# %%
# Checking is there is any null rows present inn our data
data.isna().any(axis=1).sum()
# Out:
# 0

# %%
# Checking is there is any null rows present inn our data
data.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
for i in data.columns:
    if len(set(data[i])) > 12:
        print(i)
        
[i for i in data.columns if len(set(data[i])) > 12]
# Out:
# instant
# dteday
# temp
# atemp
# hum
# windspeed
# casual
# registered
# cnt

# %% [markdown]
# #### There are no any rows present which have all the elements as NaN, or no column present which have all the values as NaN.

# %%
# Lets change the numeric values of some columns 

# Change season neumeric value using this dict {1:'spring', 2:'summer', 3:'fall', 4:'winter'}

season_dict = {1:'spring', 2:'summer', 3:'fall', 4:'winter'}
data[['season']] = data[['season']].apply(lambda x : x.map({1:'spring', 2:'summer', 3:'fall', 4:'winter'}))

# %%
# Now lets check for the mnth column.
data['dteday'] = pd.to_datetime(data['dteday'])

# %%
data['mnth'] = data['dteday'].dt.month_name()

# %%
data
# Out:
#      instant     dteday  season  yr      mnth  holiday  weekday  workingday  \
# 0          1 2018-01-01  spring   0   January        0        6           0
# 1          2 2018-02-01  spring   0  February        0        0           0
# 2          3 2018-03-01  spring   0     March        0        1           1
# 3          4 2018-04-01  spring   0     April        0        2           1
# 4          5 2018-05-01  spring   0       May        0        3           1
# ..       ...        ...     ...  ..       ...      ...      ...         ...
# 725      726 2019-12-27  spring   1  December        0        4           1
# 726      727 2019-12-28  spring   1  December        0        5           1
# 727      728 2019-12-29  spring   1  December        0        6           0
# 728      729 2019-12-30  spring   1  December        0        0           0
# 729      730 2019-12-31  spring   1  December        0        1           1
#
# ...

# %%
a = data[['weekday']].copy()

# %%
a['weekd'] = data['dteday'].dt.dayofweek

# %%
a
# Out:
#      weekday  weekd
# 0          6      0
# 1          0      3
# 2          1      3
# 3          2      6
# 4          3      1
# ..       ...    ...
# 725        4      4
# 726        5      5
# 727        6      6
# 728        0      0
# 729        1      1
#
# [730 rows x 2 columns]
